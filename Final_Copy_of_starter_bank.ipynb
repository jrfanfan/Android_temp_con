# %% [markdown]
# <a href="https://colab.research.google.com/github/jrfanfan/Android_temp_con/blob/main/Final_Copy_of_starter_bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank.csv'))
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 37064   73      retired  married  professional.course       no     yes   no
# 37065   46  blue-collar  married  professional.course       no      no   no
# 37066   56      retired  married    university.degree       no     yes   no
# 37067   44   technician  married  professional.course       no      no   no
# 37068   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 0      telephone   may         mon         1    999         0  nonexistent
# 1      telephone   may         mon         1    999         0  nonexistent
# 2      telephone   may         mon         1    999         0  nonexistent
# 3      telephone   may         mon         1    999         0  nonexistent
# 4      telephone   may         mon         1    999         0  nonexistent
# ...          ...   ...         ...       ...    ...       ...          ...
# 37064   cellular   nov         fri         1    999         0  nonexistent
# 37065   cellular   nov         fri         1    999         0  nonexistent
# 37066   cellular   nov         fri         2    999         0  nonexistent
# 37067   cellular   nov         fri         1    999         0  nonexistent
# 37068   cellular   nov         fri         3    999         1      failure
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 0               1.1          93.994          -36.4      4.857       5191.0
# 1               1.1          93.994          -36.4      4.857       5191.0
# 2               1.1          93.994          -36.4      4.857       5191.0
# 3               1.1          93.994          -36.4      4.857       5191.0
# 4               1.1          93.994          -36.4      4.857       5191.0
# ...             ...             ...            ...        ...          ...
# 37064          -1.1          94.767          -50.8      1.028       4963.6
# 37065          -1.1          94.767          -50.8      1.028       4963.6
# 37066          -1.1          94.767          -50.8      1.028       4963.6
# 37067          -1.1          94.767          -50.8      1.028       4963.6
# 37068          -1.1          94.767          -50.8      1.028       4963.6
#
#          y
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# ...    ...
# 37064  yes
# 37065   no
# 37066   no
# 37067  yes
# 37068   no
#
# [37069 rows x 20 columns]

# %%
no_term_deposit = df[df["y"]=="no"].sample(frac=0.12534615501658500958583122850796)
no_term_deposit
# Out:
#        age          job  marital            education  default housing loan  \
# 21398   35   technician  married          high.school       no      no   no
# 23451   46  blue-collar  married             basic.4y       no     yes   no
# 6466    30  blue-collar  married             basic.9y       no     yes   no
# 4920    41   technician  married  professional.course       no      no  yes
# 1201    43   technician  married    university.degree       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 22906   29   management   single    university.degree       no      no   no
# 8519    29   technician  married  professional.course       no      no   no
# 23400   39   unemployed  married             basic.9y       no      no   no
# 15434   50       admin.  married    university.degree       no     yes   no
# 11052   37  blue-collar  married             basic.6y  unknown     yes   no
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 21398   cellular   aug         thu         1    999         0  nonexistent
# 23451   cellular   nov         wed         4    999         0  nonexistent
# 6466   telephone   may         thu         1    999         0  nonexistent
# 4920   telephone   may         fri         2    999         0  nonexistent
# 1201   telephone   may         thu         4    999         0  nonexistent
# ...          ...   ...         ...       ...    ...       ...          ...
# 22906   cellular   nov         wed         1    999         0  nonexistent
# 8519   telephone   jun         fri         1    999         0  nonexistent
# 23400   cellular   nov         wed         1    999         0  nonexistent
# 15434   cellular   jul         fri         1    999         0  nonexistent
# 11052  telephone   jul         thu         1    999         0  nonexistent
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 21398           1.4          93.444          -36.1      4.962       5228.1  no
# 23451          -0.1          93.200          -42.0      4.120       5195.8  no
# 6466            1.1          93.994          -36.4      4.860       5191.0  no
# 4920            1.1          93.994          -36.4      4.857       5191.0  no
# 1201            1.1          93.994          -36.4      4.855       5191.0  no
# ...             ...             ...            ...        ...          ...  ..
# 22906          -0.1          93.200          -42.0      4.120       5195.8  no
# 8519            1.4          94.465          -41.8      4.967       5228.1  no
# 23400          -0.1          93.200          -42.0      4.120       5195.8  no
# 15434           1.4          93.918          -42.7      4.962       5228.1  no
# 11052           1.4          93.918          -42.7      4.966       5228.1  no
#
# [4119 rows x 20 columns]

# %%
# Import the seaborn library the conventional way. Then optionally configure
# the default chart style.
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
# Use seaborn to create a count plot comparing the count of single

sns.catplot(data=no_term_deposit, x='marital', kind='count')

# %%
sns.scatterplot(data= no_term_deposit, x='pdays', y='campaign', hue='y')
# Out:
# <Axes: xlabel='pdays', ylabel='campaign'>

# %%
# Create a new dataframe called X that contians the features we're going
# to use to make predictions
X = df[['campaign', 'previous', 'emp.var.rate',	'cons.price.idx',	'cons.conf.idx',	'euribor3m', 'nr.employed']]

# %%
# Create a new dataframe called y that contians the target we're
# trying to predict
y = df['y']

# %%
# Import and use the train_test_split() function to split the X and y
# dataframes into training and test sets.
#
# The training data should contain 80% of the samples and
# the test data should contain 20% of the samples.
import sklearn.model_selection
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size= 0.2)

# %%
X_train
# Out:
#        campaign  previous  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 35641         1         2          -1.8          93.876          -40.0
# 19616         1         0           1.4          93.444          -36.1
# 6309          7         0           1.1          93.994          -36.4
# 8345          2         0           1.4          94.465          -41.8
# 2960          2         0           1.1          93.994          -36.4
# ...         ...       ...           ...             ...            ...
# 9100          5         0           1.4          94.465          -41.8
# 17127         1         0           1.4          93.444          -36.1
# 33841         1         1          -2.9          92.201          -31.4
# 10962         3         0           1.4          93.918          -42.7
# 1043          2         0           1.1          93.994          -36.4
#
#        euribor3m  nr.employed
# 35641      0.677       5008.7
# 19616      4.964       5228.1
# 6309       4.860       5191.0
# 8345       4.967       5228.1
# 2960       4.860       5191.0
# ...          ...          ...
# 9100       4.958       5228.1
# 17127      4.968       5228.1
# 33841      0.861       5076.2
# 10962      4.955       5228.1
# 1043       4.856       5191.0
#
# [29655 rows x 7 columns]

# %%
y_train
# Out:
# 35641    yes
# 19616     no
# 6309      no
# 8345     yes
# 2960      no
#         ...
# 9100      no
# 17127     no
# 33841    yes
# 10962     no
# 1043      no
# Name: y, Length: 29655, dtype: object

# %%
# Import the KNeighborsClassifier class from sklearn
# Note that it's in the neighbors submodule. See the example code in the
# documentation for details on how to import it
from sklearn.neighbors import KNeighborsClassifier

# %%
# Create an instance of the model, configuring it to use the 3 nearest neighbors
# store the instance in a variable
clf = KNeighborsClassifier(n_neighbors=3)

# %%
# Call the "fit" method of the classifier instance we created in step 4.
# Pass it the X_train and y_train data so that it can learn to make predictions
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Use the predict() method to get a list of predictions for the samples in our
# test data. Then output those predictions
predictions = clf.predict(X_test)
xt = pd.DataFrame(predictions).sample(4119)
xt
xt.shape
xt.to_csv('predictions.csv', index=False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
xt.groupby(0).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Just a quick comparison with y_test to see if they match up
predictions == y_test
# Out:
# 16746    True
# 7186     True
# 18399    True
# 1042     True
# 19665    True
#          ...
# 31440    True
# 20386    True
# 27083    True
# 18753    True
# 23112    True
# Name: y, Length: 7414, dtype: bool
